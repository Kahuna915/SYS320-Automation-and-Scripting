# %% [markdown]
# # URLHAUS

# %%
import urlHaus as u
import importlib
importlib.reload(u)
# Out:
# <module 'urlHaus' from 'C:\\Users\\noahs\\PycharmProjects\\SYS320-Automation-and-Scripting\\Week03\\class\\urlHaus.py'>

# %%
u.urlHausOpen('../../logs/urlHaus.csv', ['.edu', '.gov', '.win32'])
# Out:
#                         URL: hxxp://103.171.0.134/Registry/.win32.exe
#                         Info: https://urlhaus.abuse.ch/url/2017874/
#                         ************************************************************
#
#                         URL: hxxp://lutanedukasi.co.id/wp-includes/O.exe
#                         Info: https://urlhaus.abuse.ch/url/2017838/
#                         ************************************************************
#
#                         URL: hxxp://198.46.132.195/Registry/.win32.exe
#                         Info: https://urlhaus.abuse.ch/url/2017585/
#                         ************************************************************
#
#                         URL: hxxp://103.89.90.10/Registry/.win32.exe
#                         Info: https://urlhaus.abuse.ch/url/2017583/
#                         ************************************************************
#
#                         URL: hxxp://103.171.0.134/googleCRC/.win32.exe
# ...
